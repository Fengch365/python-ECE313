# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $
# \text{a)}\ \text{Cov}(X+Y,X-Y) = \text{Cov}(X,X) + \text{Cov}(X,-Y) + \text{Cov}(Y,X) + \text{Cov}(Y,-Y)\\
# \ \ \ \ = \text{Var}(X) - \text{Cov}(X,Y) + \text{Cov}(X,Y) - \text{Cov}(Y,Y) = 20 - 20 = 0\\
# \ \ \ \ \text{$X+Y$ and $X-Y$ are uncorrelated}\\
# \text{b)}\ \text{Cov}(3X+Z, 3X+Y) = \text{Cov}(3X,3X) + \text{Cov}(3X,Y) + \text{Cov}(Z,3X) + \text{Cov}(Z,Y)\\
# \ \ \ \ = 9\text{Cov}(X,X) + 3\text{Cov}(X,Y) + 3\text{Cov}(Z,X) + \text{Cov}(Z,Y) = 245\\
# \text{c)}\ E[(X+Y)^2] = E[X^2 + 2XY + Y^2] = E[X^2] + 2E[XY] + E[Y^2]\\
# \ \ \ \ E[X^2] = \text{Var}(X) + \underbrace{E[X]^2}_{=0} = 20,\ E[Y^2] = 20\\
# \ \ \ \ E[XY] = \text{Cov}(X,Y) + \underbrace{E[X]}_{=0}E[Y] = 10\\
# \ \ \ \ \implies E[(X+Y)^2] = 20 + 2\cdot 10 + 20 = 60\\
# \text{d)}\ \hat{E}[Y+Z|X] = \underbrace{E[Y+Z]}_{=0} + \frac{\text{Cov}(X,Y+Z)}{\text{Var}(X)} (X-\underbrace{E[X]}_{=0})\\
# \ \ \ \ = \frac{\text{Cov}(X,Y) + \text{Cov}(X,Z)}{\text{Var}(X)}\cdot X = \frac{10+5}{20}X = \frac{3}{4}X\\
# \ \ \ \ \implies \hat{E}[Y+Z|X=3] = \frac{3}{4} \cdot 3 = \frac{9}{4}\\
# \text{Note: In this problem, we cannot compute $E[Y+Z|X]$, because I don't know joint distribution}
# $

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $
# X\in \{1,2,3,4,5\},\ Y\in \{1,2,3,4,5\}-\{X\}\\
# \text{a)}\ E[X] = 3\\
# \text{b)}\ \text{Var}(X) = E[X^2] - \underbrace{E[X]^2}_{=3} = \frac{1^2 + 2^2 + 3^2 + 4^2 + 5^2}{5} - 9 = 2\\
# \text{c)}\ E[XY] = \frac{2+3+4+5+6+8+10+12+15+20}{10} = \frac{85}{10} = \frac{17}{2}\\
# \ \ \ \ \text{all non-shaded squares have probability $\frac{1}{5}\cdot \frac{1}{4} = \frac{1}{20}$}
# $
# ![image.png](attachment:image.png)

# %% [markdown]
# $
# \text{d)}\ \rho = \frac{\text{Cov}(X,Y)}{\sigma_X \sigma_Y},\ \text{Cov}(X,Y) = E[XY] - E[X]E[Y]
# $

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $
# \text{a)}\ \text{If $X>0$, I know that $Y=+1$}\\
# \ \ \ \ \text{If $X<0$, I know that $Y=-1$}\\
# \ \ \ \ E[Y|X] = \begin{cases}
# +1 & \text{if}\ X\ge 0\\
# -1 & \text{if}\ X<0
# \end{cases}\\
# \text{MSE} = 0\ \text{(always estimate $Y$ exactly)}
# $
# ![image.png](attachment:image.png)

# %% [markdown]
# $
# \text{b)}\ \hat{E}[Y|X] = \underbrace{E[Y]}_{=0} + \frac{\text{Cov}(X,Y)}{\text{Var}(X)} (X-\underbrace{E[X]}_{=0})\\
# \ \ \ \ \text{$X$ is uniformly distributed in $[-2,2]$},\ \text{Var}(X) = \frac{4^2}{12} = \frac{4}{3}\\
# \ \ \ \ \text{Cov}(X,Y) = \text{Cov}(Y+N,Y) = \text{Cov}(Y,Y) + \underbrace{\text{Cov}(N,Y)}_{=0} = \text{Var}(Y) = E[Y^2] = 1\\
# \ \ \ \ \implies \hat{E}[Y|X] = \frac{1}{\frac{4}{3}} \cdot X = \frac{3}{4}X
# $
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $
# \text{a)}\ P\{Y\le -\frac{1}{3}\} = \frac{1}{4} \int_{-1}^{1} \int_{-1}^{-\frac{1}{3}}\ (uv+1)\ dvdu
# = \frac{1}{4} \int_{-1}^{1}\ \frac{uv^2}{2}+v|_{-1}^{-\frac{1}{3}}\ dv\\
# \ \ \ \ = \frac{1}{4}\int_{-1}^{1}\ (\frac{2}{3} - \frac{7u}{18})\ dv = \frac{1}{4} (\frac{2u}{3} - \frac{7u^2}{36})_{-1}^{1}
# = \frac{1}{4} \cdot \frac{4}{3} = \frac{1}{3}\\
# \text{b) constant MMSE estimator is $E[Y]$}\\
# \ \ \ \ f_Y(v) = \frac{1}{4} \int_{-1}^{1} (uv+1)\ du = \frac{1}{4} (\frac{u^2v}{2}+u)_{-1}^{1} = \frac{1}{4}\cdot 2 = \frac{1}{2}, \
# -1 < v < 1\\
# \ \ \ \ \implies \text{$Y$ is uniformly distributed in $[-1,1]$}\\
# \ \ \ \ \implies E[Y] = 0\\
# \ \ \ \ \mbox{MSE} = \mbox{Var}(Y) = \frac{2^2}{12} = \frac{1}{3}
# $
# ![image.png](attachment:image.png)

# %% [markdown]
# $
# \text{c) To find $E[Y|X]$ I need $f_{Y|X}(v|u)=\frac{f_{X,Y}(u,v)}{f_X(u)}$}\\
# \ \ \ \ \text{By symmetry, $X$ is uniformly distributed in $[-1,1]$}\\
# \ \ \ \ f_{Y|X}(v|u) = \frac{f_{XY}(u,v)}{f_X(u)} = \frac{\frac{1}{4}(uv+1)}{\frac{1}{2}} = \frac{uv+1}{2}\
# \begin{pmatrix}
# -1 < u < 1\\
# -1 < v < 1
# \end{pmatrix}\\
# \ \ \ \ E[Y|X=u] = \int_{-1}^{1}\ v f_{Y|X}(v|u)\ dv = \frac{1}{2}\int_{-1}^{1}\ (uv^2+v)\ dv
# = \frac{1}{2}(\frac{uv^3}{3} + \frac{v^2}{2})_{-1}^{1}\\
# \ \ \ \ = \frac{1}{2} \cdot \frac{2u}{3} = \frac{u}{3} \implies E[Y|X] = \frac{X}{3} \to \text{linear!}\\
# \ \ \ \ \implies \text{MSE} = E[Y^2] - E[E[Y|X]^2] = \frac{1}{3} - E[\frac{X^2}{9}]
# = \frac{1}{3} - \frac{1}{9}\cdot \frac{1}{3} = \frac{8}{27}\\
# \text{d) Since $E[Y|X]=\frac{X}{3}$ is linear in $X$,}\\
# \ \ \ \ \hat{E}[Y|X] = E[Y|X] = \frac{X}{3},\ \mbox{MSE} = \frac{8}{27}
# $

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $
# \text{a) $X$ and $X+aY$ are jointly Gaussian as well, therefore, independence is equivalent to uncorrelatedness}\\
# \ \ \ \ \text{$X$ is independent of $X+aY$ if and only if $\text{Cov}(X,X+aY)=0$}\\
# \ \ \ \ \text{Cov}(X,X+aY) = \text{Cov}(X,X) + a\text{Cov}(X,Y) = 9 + a\cdot \rho \cdot \sigma_X \sigma_Y\\
# \ \ \ \ = 9 + a\rho \cdot 6 = 0 \implies a = -\frac{3}{2\rho}\ (\text{impossible if $\rho =0$})\\
# \text{b) Cov}(X+Y,X-bY) = \text{Cov}(X,X) - b\text{Cov}(X,Y) + \text{Cov}(X,Y) - b\text{Cov}(Y,Y)\\
# \ \ \ \ \implies b = \frac{9+6\rho}{6+4\rho}\ (\text{impossible if $6+4\rho =0$})\\
# \text{d) $X+dY$ and $(X-dY)^3$, where $(X-dY)^3$ is not Gaussian. Checking independence is not equivalent to checking uncorrelatedness.}\\
# \ \ \ \ \text{However, notice that $(X-dY)^3$ is an invertible function of $X-dY$.}\\
# \ \ \ \ \text{For that reason, checking independence between $X+dY$ and $(X-dY)^3$ is}\\
# \ \ \ \ \text{the same as checking independence between $X+dY$ and $X-dY$}\\
# \ \ \ \ \text{Just need to check Cov}(X+dY, X-dY) = 0\ \text{(solving for $d$ yields $d=\pm 1.5$)}
# $
